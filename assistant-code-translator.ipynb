# %%
# %pip install openai

# %%
import os
os.environ['OPENAI_API_KEY']="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"

# %%
from openai import OpenAI
client = OpenAI(
    organization= "org-hN5rGz9V0pENCqudqQDDFKUE"
)

# %%
# Assistant(id='asst_pTuaReYlQuSYZONOknhoautt', created_at=1703240618, description=None, file_ids=[], instructions=' \nYou are an expert programmer. You have experirnce in legacy scripting languages. Your job is to interprete the legacy program and explain in plain english.\n- You are a dutch native. You are bilingual and can read and write english. \n- You can read a code and write sudo code.\n- You are an expert in understanding the code and create flow diagram.\n- You are an expert in domain driven design architecture.\n- You are expert in code review and suggest changes to followbest practices like null pointer exception, custom error handling, logging etc.\n', metadata={}, model='gpt-3.5-turbo-1106', name='Dutch Document Translator', object='assistant', tools=[])
# assistant = client.beta.assistants.create(
#     name="Dutch Document Translator",
#     instructions=""" 
# You are an expert programmer. You have experirnce in legacy scripting languages. Your job is to interprete the legacy program and explain in plain english.
# - You are a dutch native. You are bilingual and can read and write english. 
# - You can read a code and write sudo code.
# - You are an expert in understanding the code and create flow diagram.
# - You are an expert in domain driven design architecture.
# - You are expert in code review and suggest changes to followbest practices like null pointer exception, custom error handling, logging etc.
# """,
#     # tools=[{"type": "code_interpreter"}],
#     model="gpt-3.5-turbo-1106"
# )

# print(assistant)
assistant = client.beta.assistants.retrieve(assistant_id="asst_pTuaReYlQuSYZONOknhoautt")
# Out:
# Assistant(id='asst_pTuaReYlQuSYZONOknhoautt', created_at=1703240618, description=None, file_ids=[], instructions=' \nYou are an expert programmer. You have experirnce in legacy scripting languages. Your job is to interprete the legacy program and explain in plain english.\n- You are a dutch native. You are bilingual and can read and write english. \n- You can read a code and write sudo code.\n- You are an expert in understanding the code and create flow diagram.\n- You are an expert in domain driven design architecture.\n- You are expert in code review and suggest changes to followbest practices like null pointer exception, custom error handling, logging etc.\n', metadata={}, model='gpt-3.5-turbo-1106', name='Dutch Document Translator', object='assistant', tools=[])

# %%
# Thread(id='thread_ASL0QOP7n3YeiK0yrdNCQ1Yf', created_at=1703240672, metadata={}, object='thread')
# thread = client.beta.threads.create()
thread = client.beta.threads.retrieve(thread_id="thread_ASL0QOP7n3YeiK0yrdNCQ1Yf")
print(thread)
# Out:
# Thread(id='thread_ASL0QOP7n3YeiK0yrdNCQ1Yf', created_at=1703240672, metadata={}, object='thread')

# %%
thread_message = client.beta.threads.messages.create(
  thread_id= thread.id,
  role="user",
  content="Explain the given code in plain English in markdown language"
)

# %%
code_text = """ 
0007¦1=0017¦2=Invoer factuurregels¦4=AEVZT3¦14=Factuur¦15=0440¦16=444A¦17=1490X 451X 452X 421X 455X 118X 201X 443X 442X 422X 427X 426X¦23=
#	H0017 - invoer factuurregels 
#	(combi van artikelen en teksten op basis van volgnummer)

#	12-01-2009 [JB] locking aangepast aan standaard R777
#	de variabele %key777 wordt gevuld in het fieldscript van F425
#	en daar wordt ook de locking getest cq. gezet

#	NOG DOEN?
#	- testen op cashweb of de drop-downboxes breed genoeg zijn
#	- barcodes printen (vraag van pascal) (bij inboeken inkoopfactuur?)
#	- artikelgroep inbouwen bij de artikelcode? (S6)
#	- veld 1497 weer terug inbouwen in D711?

#	EIGENSCHAPPEN (in functie-eigenschap of fatureringsparameters):
#	A - het veld aaantal wordt altijd op 1 gezet en scan-mode aan
#	p - de prijs cq korting mag niet worden gewijzigd

:begin
	if $iden[6,10] = 'H0021'
		lock_test 961
		if %LOCK = 1 error "Factureringsparameters 1"," geblokkeerd, eerst vrijmaken"
		set %3274,'Offerte'
	else
		set %3274,''
	end
	zero %contant,%periodiek
	if $iden1[6,10] = 'S0711' set %contant,1
	if flagF($license) = 1 set %periodiek,1
	if flagZ($license) = 1 set %periodiek,1
	if %contant = 1 set %periodiek,0

	if #1487!101 = 'J' error "Relatie ",%HEAD0," is geblokkeerd"

	set %C1,1
	set %C2,5
	set %C3,19
	set %C4,60
	set %C5,72
	set %C6,87
	set %C7,95
	set %C8,102
	set %C9,104
	set %C10,106
	set %C11,108
	set %C12,115
	set %C13,122
	if %periodiek = 0
		column %C1,%C2,%C3,%C4,%C5,%C6,%C7,%C8,%C9,%C10
		column_kop %C1,%C2,%C3,%C4,%C5,%C6,%C7,%C8,%C9,%C10
	end
	if %periodiek = 1
		column %C1,%C2,%C3,%C4,%C5,%C6,%C7,%C8,%C9,%C10,%C11,%C12,%C13
		column_kop %C1,%C2,%C3,%C4,%C5,%C6,%C7,%C8,%C9,%C10,%C11,%C12,%C13
	end
	read 801
	read 961
	if $status = 1 error "Eerst ","Factureringsparameters 1"," invullen"
	read 808
	if %3274 = ''
		if flagR(#845!961) != 0 set %vrg_ioref,1
		if flagR(#112!101) != 0 set %vrg_ioref,1
	end
	set %col,42
	revon
	put 1,%col," "
	put 2,%col," "
	if %vrg_ioref = 1
		set %col2,84
		put 1,%col2," "
	end
	revoff
	set %kk,"Kortings % klant "L20
	if #118!101 != 0 put 2,1,%kk,': ',#118!101
	gosub subkop

:display 440
	put 0,%C1,#1490
	put 0,%C2,#451
	put 0,%C3,#452
	put 0,%C4,#421
	put 0,%C5,#455
	put 0,%C6,#118
	put 0,%C7,#201
	put 0,%C8,#443
	put 0,%C9,#442
	if %periodiek = 1
		put 0,%C10,#422
		if #422 = 'E' put 0,%C11,#427
		if #422 != 'E' put 0,%C11,#423
		put 0,%C12,#426
	end
	if %periodiek = 0
		put 0,%C10,#427
	end

:display 442
	put 0,%C1,#1490
	put 0,%C2,#451
	put 0,%C3,#452
	put 0,%C4,#421
	put 0,%C5,#455
	put 0,%C6,#118
	put 0,%C7,#201
	put 0,%C8,#443
	put 0,%C9,#442
	if %periodiek = 1
		put 0,%C10,#422
		if #422 = 'E' put 0,%C11,#427
		if #422 != 'E' put 0,%C11,#423
		put 0,%C12,#426
	end
	if %periodiek = 0
		put 0,%C10,#427
	end

:telrec
	set %tel,%tel+1

:hernum1
	set %val,%val+1
	strzero %val,3
	if %3274 = 'Offerte'
		set #1490!442,%val
		write 442
	else
		set #1490!440,%val
		write 440
	end

:hernum2
	set %val,%tel*%inc
	strzero %val,3
	if %3274 = 'Offerte'
		set #1490!442,%val
		write 442
	else
		set #1490!440,%val
		write 440
	end
	set %tel,%tel-1

:subkop
	revon
	set %R,3
	put %R,1," "90
	put %R,%C1,"vlg"
	put %R,%C2,"art.code"
	put %R,%C3,"omschrijving"
	put %R,%C4,"aantal"R10
	put %R,%C5,"prijs"R13
	put %R,%C6,"kort% "R6
	put %R,%C7,"gbrek"
	put %R,%C8,"pr"
	put %R,%C9,"ob"
	if %periodiek = 1
		put %R,%C10,"pc"
		put %R,%C11,"datum"
		put %R,%C12,"einde"
	end
	if %periodiek = 0
		put %R,%C10,"datum"
	end
	revoff

:lock_777
	zero %stop,%del777
	set %key777,'H0017',%HEAD0,%HEAD1
	if %3274 = 'Offerte' set %key777,'H0021',%HEAD0,%HEAD1
	set %lock777,function(tbllock,%key777,"read")
	if %lock777 != ''
		set %stop,1
	else
		set %del777,1
	end

:before table
	gosub lock_777
	if %stop = 1 
		inbuf 27
		stop 2,@425T,%INPUT
	end
	zero %tel
	if %3274 = 'Offerte'
		gosub telrec,447,%HEAD0,%HEAD1
	else
		gosub telrec,444,%HEAD0,%HEAD1
	end
	set %inc,10
	if %tel >= 100 set %inc,5
	if %tel >= 200 set %inc,3
	if %tel >= 333 set %inc,2
	if %tel >= 500 set %inc,1
	if %inc > 1 
#		eerst opnummeren met interval 1
		zero %val
		field %audit_jn,9011,9010
		if %audit_jn = 'J' audit_off
		if %3274 = 'Offerte'
			gosub_lock hernum1,447,%HEAD0,%HEAD1
		else
			gosub_lock hernum1,444,%HEAD0,%HEAD1
		end
#		dan afnummeren met interval zoals gekozen
		if %3274 = 'Offerte'
			gosubr_lock hernum2,447,%HEAD0,%HEAD1
		else
			gosubr_lock hernum2,444,%HEAD0,%HEAD1
		end
		if %audit_jn = 'J' audit_on
	end
	safe

	gosub subkop
	gosub disp_bedr
	zero %flagA,%flagP,%in451
	if flagA(%EIGEN) = 1 set %flagA,1
	if flagA(#845!961) = 1 set %flagA,1
	if %contant = 1 set %flagA,1
	set %kassa,%flagA
	if flagp(%EIGEN) = 1 set %flagP,1
	if flagP(#845!961) = 1 set %flagP,1
	if %vrg_ioref = 1 
		read 448,%HEAD0,%HEAD1
		if $status = 1 
			gosub vul_IOnummer
		else
			set %IOnummer,#3298!448
			put 1,%col2+2,"Inkoopordernummer: ",%IOnummer
		end
	end

:after table
	if %del777 = 1 set %Void,function(tbllock,%key777,"delete")
	zero %HEAD1
	zero %btw0,%btw1,%btw2,%btw3,%btwa,%btwb,%btwc
	gosub disp_bedr
	if %vrg_ioref = 1 put 1,%col2+2," "60

:after update
	if flagO(#845!961) = 1 if %3274 = 'Offerte' if %HEAD1 >= #3273!961 gosub_lock ltstoffnr,961
	gosub disp_bedr
	if %refresh = 1 refresh

:before record
	freset 4
	freset 5
	freset 6
	freset 7
	safe
	set %FIXED,""
	clm
	zero %refresh

:ltstoffnr
	set %ALFA,%HEAD1
	call 'S0836'
	set #3273!961,%ALFA
	write 961
	read 961
	free 901
	free 201

:after record
	if %3274 = 'Offerte'
		lock_test 961
		if %LOCK = 1 error "Factureringsparameters 1"," geblokkeerd, eerst vrijmaken"
		set #3277!442,1
		if #864!442 != 0
			if #443!442 = 'E' error "Regel ",#1490!442,": Indien BPM-factuur dan prijs 'inclusief btw' kiezen"
		end
		if #422!442 = '' set #422!442,'E'
		set %chkkpl,#911!442
		if #451!442 != ""
			field %chk201,201,450,#451!442
			if #981!101 != ""
				field %chktl,201,451,#451!442,#981!101
				if %chktl != ""
					field %chkob,444,809 
					if %chkob = "J" set %chk201,%chktl
				end
			end
			if %chkkpl = "" field %chkkpl,911,450,#451!442
		else
			set %chk201,#201!442
		end
		if %chk201 = "" if #455!442 != "" set %chk201,#949!961
		if %chkkpl = "" field %chkkpl,911,901,#901!961
		if %chk201 != ""
			field %210,210,201,%chk201
			if %210 = "V" 
				field %verpkpl,911,201,%chk201
				set #911!442,%verpkpl
				set %chkkpl,%verpkpl
			else
				zero %g
				if %210 = "D" 
					set %i,%chk201[1,1]+1
					set %g,#814!801[%i,%i]
				end
				if %210 = "J" set %g,"J"
				if %g = "J" if %chkkpl = "" error "Kostenplaats verplicht bij gbrek ",%chk201
				if %210 = "N" set %g,"N"
				if %g = "N" 
					if %chkkpl != "" 
						error "Kostenplaats niet toegestaan bij gbrek ",%chk201
						set #911!442,""
					end
				end
			end
			if %chkkpl != "" 
				field %911,208,911,%chkkpl
				if %911 = "J" error "Kostenplaats ",%chkkpl," heeft Code geblokkeerd"
			end
		end
	else
		if #864!440 != 0
			if #443!440 = 'E' error "Regel ",#1490!440,": Indien BPM-factuur dan prijs 'inclusief btw' kiezen"
		end
		if #422!440 = '' set #422!440,'E'
		set %chkkpl,#911!440
		if #451!440 != ""
			field %chk201,201,450,#451!440
			if #981!101 != ""
				field %chktl,201,451,#451!440,#981!101
				if %chktl != ""
					field %chkob,444,809 
					if %chkob = "J" set %chk201,%chktl
				end
			end
			if %chkkpl = "" field %chkkpl,911,450,#451!440
		else
			set %chk201,#201!440
		end
		if %chk201 = "" if #455!440 != "" set %chk201,#949!961
		if %chkkpl = "" field %chkkpl,911,901,#901!961
		if %chk201 != ""
			field %210,210,201,%chk201
			if %210 = "V" 
				field %verpkpl,911,201,%chk201
				set #911!440,%verpkpl
				set %chkkpl,%verpkpl
			else
				zero %g
				if %210 = "D" 
					set %i,%chk201[1,1]+1
					set %g,#814!801[%i,%i]
				end
				if %210 = "J" set %g,"J"
				if %g = "J" if %chkkpl = "" error "Kostenplaats verplicht bij gbrek ",%chk201
				if %210 = "N" set %g,"N"
				if %g = "N" 
					if %chkkpl != "" 
						error "Kostenplaats niet toegestaan bij gbrek ",%chk201
						set #911!440,""
					end
				end
			end
			if %chkkpl != "" 
				field %911,208,911,%chkkpl
				if %911 = "J" error "Kostenplaats ",%chkkpl," heeft Code geblokkeerd"
			end
		end
	end

:tellen
	set %bpm,0
	set %bedr,#455*(10000-#118)//10000*#421//100
	if #864 != 0
		set %bpm,#864
		set %deel1,#865
		set %deel2,$sysdate
		call "S0794"
		set %bedr,%bedr-%bpm
	end

	read 101,%HEAD0
	set %V207,#201
	set %V203,%bedr
	set %V206,#442
	set %V443,#443
	if #451 != ''
		# aub geen read van 450 hier opgeven anders kan je v artikel rec aflopen bij aanmaak nwe rgl. 
		# melding : 007902
		field %V206,442,450,#451
		field %V443,443,450,#451
		if #981!101 != ''
			field %451,451,451,#451,#981!101
			if %451 > ''
				field %V201,201,451,#451,#981!101
				if %V201 != '' set %V207,%V201
				field %V442,442,451,#451,#981!101
				if %V442 != '' set %V206,%V442
			end
		end
	end
	set %boekd,$sysdate
	call "S0804"
	if %V443 = "I"
		set %excl,%excl+%V203-%btw
		set %tbtw,%tbtw+%btw
		end
	if %V443 = "E"
		set %excl,%excl+%V203
		if %V206 = "H" set %EXCLH,%EXCLH+%V203
		if %V206 = "L" set %EXCLL,%EXCLL+%V203
		if %V206 = "O" set %EXCLO,%EXCLO+%V203
		end
	set %tbpm,%tbpm+%tbpm

:clear
	confirm %janee,"Weet u zeker dat u alle regels wilt weggooien? (J/N) ",2
	if %janee = 1
		if %3274 = 'Offerte'
			gosub_lock deleten442,447,%HEAD0,%HEAD1
		else
			gosub_lock deleten440,444,%HEAD0,%HEAD1
		end
		gosub disp_bedr
		set %Void,function(tbllock,%key777,"delete")
		inbuf 27,27
	end
	
:offhist
	zero %status,%janee
	swap 'S0748'
	if %status = 'H'
		if %janee = 1
			gosub maak469,447,%HEAD0,%HEAD1
			gosub_lock deleten442,447,%HEAD0,%HEAD1
			gosub disp_bedr
			set %Void,function(tbllock,%key777,"delete")
			inbuf 27,27
		end
	end
	if %status = 'F' 
		if %janee = 1
			gosub_lock maakfact,447,%HEAD0,%HEAD1
			gosub disp_bedr
			set %Void,function(tbllock,%key777,"delete")
			inbuf 27,27
		end
	end

:print
	set %err,0
	if %3274 = 'Offerte'
		gosub testbpm,447,%HEAD0,%HEAD1
	else
		gosub testbpm,444,%HEAD0,%HEAD1
	end
	if %err > 0
		error "Eerst gegevens aanpassen"
		return
		end
	if %incl = 0 
		error "Er zijn geen bedragen te printen"
		return
		end
	set %NEXT_order,%HEAD1
	set %NEXT_direct,1
	if %3274 = 'Offerte'
		set %NEXT_fpcode,'O'
	else
		set %NEXT_fpcode,'F'
	end
	swap S0713
#	records worden gedelete in S713 / S791
	gosub disp_bedr
	set %Void,function(tbllock,%key777,"delete")
	inbuf 27

:deleten440
	delete 440

:deleten442
	delete 442

:disp_bedr
	set %excl,0
	zero %EXCLH,%EXCLL,%EXCLO
	zero %tbtw,%tbpm
	if %3274 = 'Offerte'
		gosub tellen,447,%HEAD0,%HEAD1
	else
		gosub tellen,444,%HEAD0,%HEAD1
	end
	set %btwh,%EXCLH*%hoog//10000
	set %btwl,%EXCLL*%laag//10000
	set %btwo,%EXCLO*%overig//10000
	set %incl,%excl+%btwh+%btwl+%btwo+%tbtw
	set %valuta,#927!801
	if %incl+%tbpm = 0 set %valuta,"    "
	put 1,%col+2,"Totaal excl.BTW:",%excl+%tbpm," ",%valuta
	put 2,%col+2,"Totaal incl.BTW:",%incl+%tbpm," ",%valuta

:extra
	init_lock 386
	if %3274 = 'Offerte'
		set #101!386,#101!442
		set #425!386,#425!442
		set #1490!386,#1490!442
		set #911!386,#911!442
		set #427!386,#427!442
		set #440!386,#440!442
		set #1340!386,#1340!442
		set #1341!386,#1341!442
		set #864!386,#864!442
		set #865!386,#865!442
		set #1049!386,#1049!442
		set #1300!386,#1300!442
		set #1777!386,#1777!442
	else
		set #101!386,#101!440
		set #425!386,#425!440
		set #1490!386,#1490!440
		set #911!386,#911!440
		set #427!386,#427!440
		set #440!386,#440!440
		set #1340!386,#1340!440
		set #1341!386,#1341!440
		set #864!386,#864!440
		set #865!386,#865!440
		set #1049!386,#1049!440
		set #1300!386,#1300!440
		set #1777!386,#1777!440
	end
	write 386
	safe
	swap D0386
	if %3274 = 'Offerte'
		read_lock 386,#101!442,#425!442
		set #911!442,#911!386
		set #427!442,#427!386
		set #440!442,#440!386
		set #1340!442,#1340!386
		set #1341!442,#1341!386
		set #864!442,#864!386
		set #865!442,#865!386
		set #1049!442,#1049!386
		set #1300!442,#1300!386
		set #1777!442,#1777!386
	else
		read_lock 386,#101!440,#425!440
		set #911!440,#911!386
		set #427!440,#427!386
		set #440!440,#440!386
		set #1340!440,#1340!386
		set #1341!440,#1341!386
		set #864!440,#864!386
		set #865!440,#865!386
		set #1049!440,#1049!386
		set #1300!440,#1300!386
		set #1777!440,#1777!386
	end
	delete 386
	safe
	gosub disp_bedr

:testbpm
	if #864 = 0 return
	if #455 = 0
		set %err,%err+1
		error @1490Q," ",#1490,": heeft BPM-bedrag en geen regel-bedrag."
		end
	if #697!961 = ""
		set %err,%err+1
		error "Eerst ",@697Q," invullen in factureringsparameters."
		end
	field %242,242,201,#697!961
	if %242 != "N"
		set %err,%err+1
		error @697Q," ",#697!961," moet ",@242Q," [N] hebben."
		end
	if #443 != 'I'
		set %err,%err+1
		error @1490Q," ",#1490,": moet 'Soort Prijs' I hebben."
		end

:lees807
	if #700 > $sysdate return
	set %hoog,#754
	set %laag,#755
	set %overig,#761

:input 3274
	if %3274 = 'Offerte'
		put 1,23,'Offerte'
	else
		set %NEXT_3274,''
		put 1,23,'Factuur'
	end

:input 425
	if %3274 = 'Offerte'
		set %425,#3273!961
		put 1,1,"Offertenummer  "
		get 1,23,#425,%425,'FG'
		set #425!442,%425
		if %425 < #3273!961
			zero %teloff
			gosub teloff,447,%HEAD0,%425
			if %teloff = '' message @3273T," in parameters is hoger."
		end
	else
		zero %425
		put 1,1,"Orderreferentie"
		get 1,23,#425,%425,'FG'
		set #425!440,%425
	end
	put 1,23,%425

:input 1490
	freset 4
	freset 5
	freset 6
	freset 7
	freset 8
	if %3274 = 'Offerte'
		set %volg,#1490!442
	else
		set %volg,#1490!440
	end
	if %in451 = 1 zero %kassa
	if %kassa = 1
		if %MODE = '1'
			if %3274 = 'Offerte'
				lastkey %volg,447,%HEAD0,%HEAD1
			else
				lastkey %volg,444,%HEAD0,%HEAD1
			end
			set %volg,%volg+2
			strzero %volg,3
			put 0,%C1,%volg
			if %3274 = 'Offerte'
				set #1490!442,%volg
			else
				set #1490!440,%volg
			end
			zero %in451
			return
		end
	end
	if %MODE = '1' 
		fswap 4,S0153
		fgosub 5,clear,"Wissen","","Wissen order"
		if flagO(#845!961) = 1 if %3274 = 'Offerte' fgosub 6,offhist,'Status',"","Offerte naar historie"
		if %vrg_ioref = 1 if %3274 != 'Offerte' fgosub 6,vul_IOnummer,'InkOrder',"","Wijzig Inkooporder"
		fgosub 7,print,'Print',"","Print factuur"
		if %contant = 0 fswap 8,M0147
		if %3274 = 'Offerte'
			lastkey %volg,447,%HEAD0,%HEAD1
		else
			lastkey %volg,444,%HEAD0,%HEAD1
		end
		set %volg,%volg+%inc
	end
	if (%volg) > 999 set %volg,'999'
	strzero %volg,3
	if %janee = 1
		inbuf 27
		zero %janee
	end
	get 0,%C1,#1490,%volg,'F'
	if (%volg) < 1 error "Geldig volgnummer 1 t/m 999"
	zero %testvolg
	if %3274 = 'Offerte'
		if %volg != #1490^442 set %testvolg,1
	else
		if %volg != #1490^440 set %testvolg,1
	end
	if %testvolg = 1
		zero %hit
		if %3274 = 'Offerte'
			gosub testvolg,447,%HEAD0,%HEAD1,%volg,_[255]
		else
			gosub testvolg,444,%HEAD0,%HEAD1,%volg,_[255]
		end
		if %hit = 1 
			if %volg < '999' error "Volgnummer ",%volg," bestaat al, andere kiezen svp"
			if %volg = '999' error "Gebruik ESC om regels te hernummeren svp"
		end
	end
	if %3274 = 'Offerte'
		set #1490!442,%volg
		if #1490!442 != #1490^442 set %refresh,1
	else
		set #1490!440,%volg
		if #1490!440 != #1490^440 set %refresh,1
	end

:input 451
	set %in451,1
	if %3274 = 'Offerte'
		set %w,#451!442
		get 0,%C2,#451,%w,'iJ'
		set #451!442,%w
		if #451!442 > '' if #451!442 != #451!450 read 450,%w
	else
		set %w,#451!440
		get 0,%C2,#451,%w,'iJ'
		set #451!440,%w
		if #451!440 > '' if #451!440 != #451!450 read 450,%w
	end
	if %w = '' 
		set %kassa,0
	else
		set %kassa,%flagA
	end
	zero %in451
	fgosub 6,extra,'Extra',"","Extra velden"

:input 452
	if %3274 = 'Offerte'
		if #451!442 != '' 
			# Als omschrijving leeg van zowel artikel als taalcode/artikel
			# dan wordt alsnog om omschrijving gevraagd. (funtionaliteit van A-versie extra tekst)
			read 451,#451!450,#981!101
			set %test,#452!450,#453!450,#454!450,#452!451,#453!451,#454!451
			strtrunc %test
			put 0,%C3,#452!450
			if %test != "" set #452!442,#452!450
			if %MODE = 0 if #451^442 = '' set #452!442,''
			if %test != "" return
		end
		set %w,#452!442
		get 0,%C3,#452,%w
		set #452!442,%w
	else
		if #451!440 != '' 
			# Als omschrijving leeg van zowel artikel als taalcode/artikel
			# dan wordt alsnog om omschrijving gevraagd. (funtionaliteit van A-versie extra tekst)
			read 451,#451!450,#981!101
			set %test,#452!450,#453!450,#454!450,#452!451,#453!451,#454!451
			strtrunc %test
			put 0,%C3,#452!450
			if %test != "" set #452!440,#452!450
			if %MODE = 0 if #451^440 = '' set #452!440,''
			if %test != "" return
		end
		set %w,#452!440
		get 0,%C3,#452,%w
		set #452!440,%w
	end

:input 421
	if %kassa = 1
		if %MODE = '1'
			if %3274 = 'Offerte'
				set #421!442,100
				put 0,%C4,#421!442
				return
			else
				set #421!440,100
				put 0,%C4,#421!440
				return
			end
		end
	end
	if %3274 = 'Offerte'
		set %w,#421!442
		if #451!442 > '' get 0,%C4,#421,%w,'M'
		if #451!442 = '' get 0,%C4,#421,%w
		set #421!442,%w
		put 0,%C4,#421!442
	else
		set %w,#421!440
		if #451!440 > '' get 0,%C4,#421,%w,'M'
		if #451!440 = '' get 0,%C4,#421,%w
		set #421!440,%w
		put 0,%C4,#421!440
	end

:input 455
	if %3274 = 'Offerte'
		if #421!442 = 0
			put 0,%C5,0
			set #455!442,0
			return
		end
	else
		if #421!440 = 0
			put 0,%C5,0
			set #455!440,0
			return
		end
	end
	if %3274 = 'Offerte'
		if #451!442 > ''
			if #451!442 != #451^442 set #455!442,#455!450
			if %MODE = 1
				put 0,%C5,#455!450
				set #455!442,#455!450
			end
			if %flagP = 1 return
		end
		set %w,#455!442
		get 0,%C5,#455,%w
		set #455!442,%w
		# Indien artikelcode gevuld, aantal met rust laten
		if #451!442 = ''
			if #455!442 = 0
				set #421!442,0
				put 0,%C4,#421!442
			end
		end
	else
		if #451!440 > ''
			if #451!440 != #451^440 set #455!440,#455!450
			if %MODE = 1
				put 0,%C5,#455!450
				set #455!440,#455!450
			end
			if %flagP = 1 return
		end
		set %w,#455!440
		get 0,%C5,#455,%w
		set #455!440,%w
		# Indien artikelcode gevuld, aantal met rust laten
		if #451!440 = ''
			if #455!440 = 0
				set #421!440,0
				put 0,%C4,#421!440
			end
		end
	end

:input 118
	if %kassa = 1
		if %3274 = 'Offerte'
			if #118!442 = 0 set #118!442,#118!101
			put 0,%C6,#118!442
			return
		else
			if #118!440 = 0 set #118!440,#118!101
			put 0,%C6,#118!440
			return
		end
	end
	zero %zero
	if %3274 = 'Offerte'
		if #451!442 > '' 
			if %flagP = 1 return
			if #457!450 = 'G' set %zero,1
		end
		if #421!442 = 0 set %zero,1
	else
		if #451!440 > '' 
			if %flagP = 1 return
			if #457!450 = 'G' set %zero,1
		end
		if #421!440 = 0 set %zero,1
	end
	if %zero = 1
		if %3274 = 'Offerte'
			set #118!442,0
			put 0,%C6,#118!442
			return
		else
			set #118!440,0
			put 0,%C6,#118!440
			return
		end
	end
	if %3274 = 'Offerte'
		set %w,#118!442
	else
		set %w,#118!440
	end
	if %w = 0
		if %MODE = 1 set %w,#118!101
		if #457!450 = 'R' set %w,#118!101
	end
	get 0,%C6,#118,%w
	if %3274 = 'Offerte'
		set #118!442,%w
		put 0,%C6,#118!442
	else
		set #118!440,%w
		put 0,%C6,#118!440
	end

:input 201
	if %3274 = 'Offerte'
		if #421!442 = 0
			put 0,%C7,'      '
			set #201!442,''
			return
		end
		if #451!442 != ''
			put 0,%C7,'      '
			set #201!442,''
			return
		end
		set %w,#201!442
		get 0,%C7,#201,%w,'J'
		set #201!442,%w
	else
		if #421!440 = 0
			put 0,%C7,'      '
			set #201!440,''
			return
		end
		if #451!440 != ''
			put 0,%C7,'      '
			set #201!440,''
			return
		end
		set %w,#201!440
		get 0,%C7,#201,%w,'J'
		set #201!440,%w
	end
		
:input 443
	if %3274 = 'Offerte'
		if #421!442 = 0
			put 0,%C8,' '
			set #443!442,''
			return
		end
		if #451!442 != ''
			put 0,%C8,#443!450
			set #443!442,#443!450
			return
		end
		set %w,#443!442
		get 0,%C8,#443,%w
		set #443!442,%w
	else
		if #421!440 = 0
			put 0,%C8,' '
			set #443!440,''
			return
		end
		if #451!440 != ''
			put 0,%C8,#443!450
			set #443!440,#443!450
			return
		end
		set %w,#443!440
		get 0,%C8,#443,%w
		set #443!440,%w
	end

:input 442
	if %3274 = 'Offerte'
		if #421!442 = 0
			put 0,%C9,' '
			set #442!442,''
			return
		end
		if #451!442 != ''
			set #442!442,#442!450
			if #981!101 != ''
				read 451,#451!442,#981!101
				if $status = 0
					if #442!451 != '' set #442!442,#442!451
				end
			end
			put 0,%C9,#442!442
			return
		end
		set %w,#442!442
		if %w = ''
			read 201,#201!442
			if #201!442 = '' read 201,#949!961
			set %w,#242!201
		end
		get 0,%C9,#442,%w
		set #442!442,%w
	else
		if #421!440 = 0
			put 0,%C9,' '
			set #442!440,''
			return
		end
		if #451!440 != ''
			set #442!440,#442!450
			if #981!101 != ''
				read 451,#451!440,#981!101
				if $status = 0
					if #442!451 != '' set #442!440,#442!451
				end
			end
			put 0,%C9,#442!440
			return
		end
		set %w,#442!440
		if %w = ''
			read 201,#201!440
			if #201!440 = '' read 201,#949!961
			set %w,#242!201
		end
		get 0,%C9,#442,%w
		set #442!440,%w
	end

:input 422
	if %periodiek = 0 return
	if %3274 = 'Offerte'
		set %w,#422!442
		if %w = '' set %w,'E'
		get 0,%C10,#422,%w
		if %w = 'Z' 
			set %period,#1919!442
			put mess,1,@1919
			get mess,23,#1919,%period
			set #1919!442,%period
		end
		set #422!442,%w
	else
		set %w,#422!440
		if %w = '' set %w,'E'
		get 0,%C10,#422,%w
		if %w = 'Z' 
			set %period,#1919!440
			put mess,1,@1919
			get mess,23,#1919,%period
			set #1919!440,%period
		end
		set #422!440,%w
	end

:input 427
	if %periodiek = 1
		if %3274 = 'Offerte'
			set %w,#423!442
			if #422!442 = 'E' set %w,#427!442
			get 0,%C11,#427,%w
			if #422!442 != 'E' if %w = '' error
			if #422!442 = 'E' 
				set #427!442,%w
				set #423!442,''
			end
			if #422!442 != 'E' set #423!442,%w
		else
			set %w,#423!440
			if #422!440 = 'E' set %w,#427!440
			get 0,%C11,#427,%w
			if #422!440 != 'E' if %w = '' error
			if #422!440 = 'E' 
				set #427!440,%w
				set #423!440,''
			end
			if #422!440 != 'E' set #423!440,%w
		end
	end
	if %periodiek = 0
		if %3274 = 'Offerte'
			set %w,#427!442
			get 0,%C10,#427,%w
			set #427!442,%w
		else
			set %w,#427!440
			get 0,%C10,#427,%w
			set #427!440,%w
		end
	end

:input 426
	if %periodiek = 0 return
	if %3274 = 'Offerte'
		if #422!442 = 'E'
			set #426!442,''
			put 0,%C12,'      '
			return
		end
		set %w,#426!442
		get 0,%C12,#426,%w
		set #426!442,%w
	else
		if #422!440 = 'E'
			set #426!440,''
			put 0,%C12,'      '
			return
		end
		set %w,#426!440
		get 0,%C12,#426,%w
		set #426!440,%w
	end

:char
	set %c,%w[%i,%i]
	if %c = '-'
		set %sign,-1
		return
	end
	if %c = ','
		set %dec,1
		return
	end
	if %dec = 1 
		set %v2,%v2,%c
		set %ndec,%ndec+1
	end
	if %dec = 0
		set %v1,%v1,%c
	end

:testvolg
	if #1490 = %volg set %hit,1
	set %EXIT,1

:maak469
	init_lock 469
	set #3277!469,3
	set #101!469,%HEAD0
	set #302!469,$sysdate
	set #425!469,%HEAD1
	set #1490!469,#1490!442
	set #451!469,#451!442
	set #452!469,#452!442
	set #442!469,#442!442
	set #443!469,#443!442
	set #421!469,#421!442
	set #427!469,#427!442
	set #118!469,#118!442
	set #455!469,#455!442
	write 469

:maakfact
	set #3277!442,2
	buildw 440,442
	field %421,421,444,#101!442,#425!442,#1490!442
	if %421 = 100 
		if #421!442 = 0
			read_lock 440,#101!442,#425!442,#1490!442
			set #421!440,0
			write 440
		end
	end
	delete 442

:teloff
	set %teloff,1
	set %EXIT,1

:douploaded
	if %3274 = 'Offerte'
		set #1777!442,%UPLOADED
	else
		set #1777!440,%UPLOADED
	end
	put mess,1,"Bestand geupload: ",%UPLOADED

:vul_IOnummer
	set %IOnummer,#3298!448
	set %NEXT_IOnummer,#3298!448
	zero %wissen
	swap 'S0443'
	if %wissen = 'J' zero %IOnummer
	if %IOnummer != #3298!448
		read_lock 448,%HEAD0,%HEAD1
		if %wissen = 'J' 
			delete 448
			free 448
		else
			set #101!448,%HEAD0
			set #425!448,%HEAD1
			set #3298!448,%IOnummer
			write 448
		end
	end
	put 1,%col2+2," "60
	put 1,%col2+2,"Inkoopordernummer: ",%IOnummer
¦28=101AG 425FX¦31=EFI¦86=123¦
""".strip()

# Split the string into lines
formatted_string = code_text.replace('\n', '\\n')

# %%
print(formatted_string)
# Out:
# 0007¦1=0017¦2=Invoer factuurregels¦4=AEVZT3¦14=Factuur¦15=0440¦16=444A¦17=1490X 451X 452X 421X 455X 118X 201X 443X 442X 422X 427X 426X¦23=\n#	H0017 - invoer factuurregels \n#	(combi van artikelen en teksten op basis van volgnummer)\n\n#	12-01-2009 [JB] locking aangepast aan standaard R777\n#	de variabele %key777 wordt gevuld in het fieldscript van F425\n#	en daar wordt ook de locking getest cq. gezet\n\n#	NOG DOEN?\n#	- testen op cashweb of de drop-downboxes breed genoeg zijn\n#	- barcodes printen (vraag van pascal) (bij inboeken inkoopfactuur?)\n#	- artikelgroep inbouwen bij de artikelcode? (S6)\n#	- veld 1497 weer terug inbouwen in D711?\n\n#	EIGENSCHAPPEN (in functie-eigenschap of fatureringsparameters):\n#	A - het veld aaantal wordt altijd op 1 gezet en scan-mode aan\n#	p - de prijs cq korting mag niet worden gewijzigd\n\n:begin\n	if $iden[6,10] = 'H0021'\n		lock_test 961\n		if %LOCK = 1 error "Factureringsparameters 1"," geblokkeerd, eerst vrijmaken"\n		set %3274,'Offerte'\n	els
# ...

# %%
thread_message = client.beta.threads.messages.create(
  thread_id= thread.id,
  role="user",
  content= formatted_string
)

# %%
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# %%
# Periodically retrieve the Run to check status and see if it has completed
# Should print "in_progress" several times before completing
while run.status != "completed":
    keep_retrieving_run = client.beta.threads.runs.retrieve(
        thread_id=thread.id,
        run_id=run.id
    )
    print(f"Run status: {keep_retrieving_run.status}")

    if keep_retrieving_run.status == "completed":
        print("\n")
        break
# Out:
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# ...

# %%
# Retrieve messages added by the Assistant to the thread
all_messages = client.beta.threads.messages.list(
    thread_id=thread.id
)

print(all_messages.data[0].content[0].text.value)
# Out:
# ```markdown
# The given code is written in a legacy language and appears to be a combination of variable assignments, conditional statements, function calls, and comments.
#
# It is not possible to understand the complete functionality. But the code seems to be manipulating and processing invoicing data, handling locking parameters, input validation, and printing functionality.
#
# The code includes comments in the form of lines starting with '#', which provide explanations and to-do lists for future work.
#
# Some of the key functionalities include:
# - Reading and validating input data related to invoices and orders
# - Setting and verifying locking parameters for invoices
# - Handling numbering and printing of invoices and orders
# - Processing and displaying invoice details
# - Handling additional fields and extra functionality for invoices
# - Error handling and data manipulation based on certain conditions
#
# ...

# %%
thread_message = client.beta.threads.messages.create(
  thread_id= thread.id,
  role="user",
  content="Explain each function in english. A function is identified as :name. Explain the program flow also."
)

# %%
thread_message = client.beta.threads.messages.create(
  thread_id= thread.id,
  role="user",
  content= formatted_string
)

# %%
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# %%
# Periodically retrieve the Run to check status and see if it has completed
# Should print "in_progress" several times before completing
while run.status != "completed":
    keep_retrieving_run = client.beta.threads.runs.retrieve(
        thread_id=thread.id,
        run_id=run.id
    )
    print(f"Run status: {keep_retrieving_run.status}")

    if keep_retrieving_run.status == "completed":
        print("\n")
        break
# Out:
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: completed

# %%
# Retrieve messages added by the Assistant to the thread
all_messages = client.beta.threads.messages.list(
    thread_id=thread.id
)

print(all_messages.data[0].content[0].text.value)
# Out:
# This legacy script is using a custom language to define functions and their execution flow. Here's the explanation of the script:
#
# 1. The script begins with some comments mentioning the purpose and history of the script.
#
# 2. The `:begin` function contains conditions to set values based on conditions and flags.
#
# 3. The `:display` functions are responsible for displaying data in specific columns.
#
# 4. The `:telrec`, `:hernum1`, `:hernum2`, and `:subkop` functions are helper functions to perform specific operations for record numbering and subheading.
#
# 5. The `:lock_777` function is responsible for locking specific records based on conditions.
#
# 6. The script contains `:before table`, `:after table`, `:after update`, `:before record`, and `:after record` functions, which are executed before and after specific table operations, record operations, and updates.
#
# ...

# %%
thread_message = client.beta.threads.messages.create(
  thread_id= thread.id,
  role="user",
  content="For the given code create a flowchart diagram using mermaidjs format."
)

# %%
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# %%
# Periodically retrieve the Run to check status and see if it has completed
# Should print "in_progress" several times before completing
while run.status != "completed":
    keep_retrieving_run = client.beta.threads.runs.retrieve(
        thread_id=thread.id,
        run_id=run.id
    )
    print(f"Run status: {keep_retrieving_run.status}")

    if keep_retrieving_run.status == "completed":
        print("\n")
        break
# Out:
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# ...

# %%
# Retrieve messages added by the Assistant to the thread
all_messages = client.beta.threads.messages.list(
    thread_id=thread.id
)

print(all_messages.data[0].content[0].text.value)
# Out:
# Certainly! Here's the flowchart diagram for the given code using the MermaidJS format:
#
# ```mermaid
# graph LR
#     begin((begin)) --> |$iden[6,10] = 'H0021'| lock_test
#     lock_test --> |%LOCK = 1| error
#     lock_test --> |%LOCK != 1| set_3274
#     set_3274 --> stop
#     set_3274 --> contant_periodiek
#     contant_periodiek --> stop
#     contant_periodiek --> contant_periodiekSetters
#     contant_periodiekSetters --> stop
#     contant_periodiekSetters --> check_1487
#     check_1487 --> |#1487!101 = 'J'| error_relatie_geblokkeerd
#     check_1487 --> |#1487!101 != 'J'| column_settings
#     column_settings --> read_801
#     read_801 --> read_961
#     read_961 --> |$status = 1| error
#     read_961 --> read_808
#     read_808 --> |%3274 = ''| flag_checks
#     flag_checks --> |flagR(#845!961) != 0| set_vrg_ioref
#     flag_checks --> |flagR(#112!101) != 0| set_vrg_ioref
#     set_vrg_ioref --> set_col
#     set_col --> revon_revoff
#     revon_revoff --> put_records
# ...

# %%
thread_message = client.beta.threads.messages.create(
  thread_id= thread.id,
  role="user",
  content="For the given code create a sequence diagram using mermaidjs format."
)

run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Periodically retrieve the Run to check status and see if it has completed
# Should print "in_progress" several times before completing
while run.status != "completed":
    keep_retrieving_run = client.beta.threads.runs.retrieve(
        thread_id=thread.id,
        run_id=run.id
    )
    print(f"Run status: {keep_retrieving_run.status}")

    if keep_retrieving_run.status == "completed":
        print("\n")
        break
    
# Retrieve messages added by the Assistant to the thread
all_messages = client.beta.threads.messages.list(
    thread_id=thread.id
)

print(all_messages.data[0].content[0].text.value)
# Out:
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# ...

# %%
thread_message = client.beta.threads.messages.create(
  thread_id= thread.id,
  role="user",
  content="For the given code generate sudo code."
)

run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Periodically retrieve the Run to check status and see if it has completed
# Should print "in_progress" several times before completing
while run.status != "completed":
    keep_retrieving_run = client.beta.threads.runs.retrieve(
        thread_id=thread.id,
        run_id=run.id
    )
    print(f"Run status: {keep_retrieving_run.status}")

    if keep_retrieving_run.status == "completed":
        print("\n")
        break
    
# Retrieve messages added by the Assistant to the thread
all_messages = client.beta.threads.messages.list(
    thread_id=thread.id
)

print(all_messages.data[0].content[0].text.value)
# Out:
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: completed
#
#
# ...

# %%
thread_message = client.beta.threads.messages.create(
  thread_id= thread.id,
  role="user",
  content="Generate python code for begin function."
)

run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Periodically retrieve the Run to check status and see if it has completed
# Should print "in_progress" several times before completing
while run.status != "completed":
    keep_retrieving_run = client.beta.threads.runs.retrieve(
        thread_id=thread.id,
        run_id=run.id
    )
    print(f"Run status: {keep_retrieving_run.status}")

    if keep_retrieving_run.status == "completed":
        print("\n")
        break
    
# Retrieve messages added by the Assistant to the thread
all_messages = client.beta.threads.messages.list(
    thread_id=thread.id
)

print(all_messages.data[0].content[0].text.value)
# Out:
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# ...

# %%
# %pip install pypdf

# %%
from langchain.document_loaders import PyPDFLoader

loader = PyPDFLoader("docs/Commandos.pdf")
pages = loader.load_and_split()

# %%
print(pages[0].page_content)

# %%
page_count = 1
for page in pages:
    thread_message = client.beta.threads.messages.create(
        thread_id= thread.id,
        role="user",
        content= page.page_content
    )

    run = client.beta.threads.runs.create(
        thread_id=thread.id,
        assistant_id=assistant.id
    )

    while run.status != "completed":
        keep_retrieving_run = client.beta.threads.runs.retrieve(
            thread_id=thread.id,
            run_id=run.id
        )
        print(f"Run status: {keep_retrieving_run.status}")

        if keep_retrieving_run.status == "completed":
            break

    all_messages = client.beta.threads.messages.list(
        thread_id=thread.id
    )


    new_file_path = f"docs/translated-{page_count}.md"
    with open(new_file_path, 'w') as file:
        file.write(all_messages.data[0].content[0].text.value)
    
    page_count += 1
    if page_count == 4:
        break
